# %% [markdown]
# # 1 - Primeiro plot

# %%
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [1, 2, 3, 2.5, 4, 5.5, 3]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# # 2 - Labels

# %%
plt.labelx("Tempo")
plt.()
